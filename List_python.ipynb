# %%
# Name of Data Structures
#1.List
#2.Tuple
#3.Set
#4.Dictionary(dict)

# That bellow data structures we used with the help of packages(libraries)
#5.Array
#6.Series
#7.DataFrames

# %% [markdown]
# ## 1.List
# * 1.Homogeneous and hetrogeneous
# * 2.Mutable
# * 3.Access based on +ve and -ve indexing
# * 4.syntax: [,]

# %%
l1=[10,20,30,40,50,60,70,80] # Homogeneous list
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l2=[10,20.5,30,True,'Keshav',56+7j] # Hetrogenous list ,it collects multiple data type so thats why

# %%
l2
# Out:
# [10, 20.5, 30, True, 'Keshav', (56+7j)]

# %%
l2.append(70) # Adds only one item
              # Cannot add multiple items
l2
# Out:
# [10, 20.5, 30, True, 'Keshav', (56+7j), 70]

# %%
l2
l2.extend([50,40,604,85.5])  #Accepts any iterable (list, tuple, set)
l2
# Out:
# [10, 20.5, 30, True, 'Keshav', (56+7j), 70, 50, 40, 604, 85.5]

# %% [markdown]
# * insert(index, value)

# %%
l2.insert(2,'bro') # get two parameters (index, value) and add it
l2
# Out:
# [10, 20.5, 'bro', 30, True, 'Keshav', (56+7j), 70, 50, 40, 604, 85.5]

# %%
l2.remove([50,40,604,85.5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l2.remove([50,40,604,85.5])
#
# ValueError: list.remove(x): x not in list

# %%
# var_name.remove(value)
l2.remove(70) #Removes first occurrence of value    #Error if value not found

# %%
l2

# %%
# default pop removes value which present in last  
# syntax pop(index number)

l2.pop(2) # remove present element of that given index 
l2

# %%
# if u dont give the index number it deafult removes the last element in the list

l2.pop() # removes last element
l2

# %%
# clear()
# Removes all elements

l2.clear() # it removes all elements in the list only the empty list are present of the list
l2

# %%
l2

# %%
l2=[10, 20.5, 30, True, 'Keshav', (56+7j), 70, 50, 40, 604, 85.5, 50, 40, 604]

# %%
#  index(value)
# Returns index of first occurrence

l2.index(30) # returns index position of the given value

# %%
#count(value)
#Counts occurrences

l2.count(50) # returns how many number in your list

# %%
#sort()
#Sorts list in place

l2.sort() # sort the list if all elements are in integer or float
l2

# %%
l1=list(range(100,4,-4)) # in step -indexing also happens but the given end position like here(4) is less than start position(100)
l1

# %%
#sort() function gives value in ascending order if u want in descending order sort(reverse=True)
l1.sort() # sort the element into ascending order
l1

# %%
l1.sort(reverse=True) # it gives values in descending order
l1

# %%
l5=l1 # it is also a method but it do
l5

# %%
# copy() # it gives u a shallow copy of that list
l3=l1.copy()
print(l3)
print(l1)

# %%
# lst2 = lst        → reference copy (both point to same list, changes affect both)
# lst2 = lst.copy() → shallow copy (new list, original list not affected)

# %%
l1.append(1)

# %%
l5 # get copy when i run that code cell again

# %%
l3 # dose not get copy the item

# %% [markdown]
# ## BUILT-IN FUNCTIONS THAT WORK ON LISTS

# %%
max(l1) # returns maximum value in the list

# %%
min(l1) # returns minimum value in the list

# %%
l2=[10,20,30,40,50,60,[10,20,30],70,80,90]

# %%
len(l1) # return the no.of present element in the list

# %%
len(l2) # list in list is consider as a only one element

# %%
sum(l1) # returns the addition of present elements in the list

# %%
sum(l2) # it doesnot work with list within list because it gives error :TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
sorted([50,405016,90,40,52,78,785,4646,4101,1,25,35,74,96]) # sort the list but it want to give all list not list object name(means variable name)

# %%
l2

# %%
print(l2)
any(l2) # it returns the true if any one element is true

# %%
l22=[10, 20.5, 30, True, 'Keshav', (56+7j), 70, 50, 40, 604, 85.5, 50, 40, 604,0]

# %%
l22
any(l22)
# Out:
# True

# %%
all(l22) # return true when all elements in list are true
# Out:
# False

# %%
#list(iterable)
#Creates list
list("abcd")
# Out:
# ['a', 'b', 'c', 'd']

# %%
l22[2] #indexing
# Out:
# 30

# %%
l22[3:5] # slicing
# Out:
# [True, 'Keshav']

# %%
l22
# Out:
# [10, 20.5, 30, True, 'Keshav', (56+7j), 70, 50, 40, 604, 85.5, 50, 40, 604, 0]

# %%
l22 * 2 #repetition add same list that much time you give
# Out:
# [10,
#  20.5,
#  30,
#  True,
#  'Keshav',
#  (56+7j),
#  70,
#  50,
#  40,
#  604,
#  85.5,
#  50,
#  40,
#  604,
#  0,
#  10,
#  20.5,
#  30,
#  True,
#  'Keshav',
#  (56+7j),
#  70,
#  50,
#  40,
#  604,
#  85.5,
#  50,
#  40,
#  604,
#  0]

# %%
'keshav' in l22 # check it present or not
# Out:
# False

# %%
50 in l22
# Out:
# True
